# %%
import numpy as np

# %%
# 1. buat vektor x ukuran 3x1
x = np.array([[3],
              [4],
              [12]])

# %%
x
# Out:
# array([[ 3],
#        [ 4],
#        [12]])

# %%
# Tampilkan L2 Norm nya

(3**2 + 4**2 + 12**2)**(1/2)
# Out:
# 13.0

# %%
# 2. membuat vektor v dengan elemen (3, 4)
x = np.array([3, 4])

# %%
x
# Out:
# array([3, 4])

# %%
# a.Tampilkan L2 Norm nya

(3**2 + 4**2)**(1/2)
# Out:
# 5.0

# %%
# b.Tampilkan unit vector dari vector x
unit_x = x / 13

print("Unit vector:", unit_x)
# Out:
# Unit vector: [0.23076923 0.30769231]

# %%
# c.hitung panjang unit vector dari vector x

print("Panjang unit vector:", np.linalg.norm(unit_x))
# Out:
# Panjang unit vector: 0.38461538461538464
