# %%
import numpy as np

# %%
x = np.array([[25], [2], [-3], [-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])
